# %%
import pyautogui as pg
import time

pg.FAILSAFE = True

# %%
pg.position()
# Out:
# Point(x=1262, y=19)

# %%
pg.size()
# Out:
# Size(width=1512, height=982)

# %%
pg.click(1262, 19, duration=1)

# %%
pg.screenshot('screenshot.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3024x1964>

# %%
pg.screenshot('screenshot.png', region=(0, 0, 100, 100))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100>
